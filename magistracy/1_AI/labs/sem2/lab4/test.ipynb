# %%
import numpy as np
from matplotlib import pyplot as plt

from data import Point_Generator
from ransac import RANSAC

# %%
p_gen = Point_Generator(100, 0.1)

# %%
data = p_gen.generate_case()

# %%
plt.scatter(data.T[0], data.T[1])

# %%
algo = RANSAC()
algo.set_case({'points' : data,
               'iter_num' : 50000,
               'online_thresh' : 0.5})
algo.fit()

# %%
algo.draw()
# Out:
# Текущий процент: 0.9
